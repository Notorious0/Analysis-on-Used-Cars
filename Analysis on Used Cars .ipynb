# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
# - Dataset contains one of the used car company sales.
#
# - Few decades sale History available on this Dataset.
#
# - It contains approx. 9k records.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
# - **Example Problem Statement:**
#
#   - In the past few years, prices of new cars have skyrocketed, due to which most people are incapable of buying a new one.
#
#   - Customers buying a new car always looks for assurity of their money to be worthy.
#
#   - But due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).
#
#   - There is a need for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
#
#   - Even though there are websites that offers this service, their prediction method may not be the best.
#
#   - Besides, different models and systems may contribute on predicting power for a used car’s actual market value.
#
#   - It is important to know their actual market value while both buying and selling.
#
# <p align="center"><img src="https://visme.co/blog/wp-content/uploads/2020/06/animated-interactive-infographics-header-wide.gif"></p>
#
# - Derive a scenario related to the problem statement and heads on to the journey of exploration.
#
# - **Example Scenario:**
#   - Cars Absolute, an American company buys and sells second hand cars.
#
#   - The company has earned its name because of sincerity in work and quality of services.
#
#   - But for past few months their sales is down for some reason and they are unable to figure it out.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version
# Out:
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
car = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('Data Shape:', car.shape)
car.head()
# Out:
# Data Shape: (9576, 10)
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
backup=car.copy()

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
car.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# ### **Data Information**

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 523.8+ KB

# %%
car.count()
# Out:
# car             9576
# price           9576
# body            9576
# mileage         9576
# engV            9142
# engType         9576
# registration    9576
# year            9576
# model           9576
# drive           9065
# dtype: int64

# %%
100*(car.shape[0]-car.count())/car.shape[0]
# Out:
# car             0.000000
# price           0.000000
# body            0.000000
# mileage         0.000000
# engV            4.532164
# engType         0.000000
# registration    0.000000
# year            0.000000
# model           0.000000
# drive           5.336257
# dtype: float64

# %% [markdown]
# ## Error in data
# - select only yes registration =Done
# - check unique in all =Done
# - some missing value| null value  in engv and drive(should be in only two front&back)=Done
# - Engtype should be in Gas petrol Diesel and other =Already Done
# - Body type-Hatchback, Sedan, Crossover,Wagon ,Van,Other= Done
# - price is already in dollar
# - check duplicates=Done
# - check  outliner in mileage and price=Done

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
car.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
car['registration'].value_counts()
# Out:
# yes    9015
# no      561
# Name: registration, dtype: int64

# %%
car=car[car['registration']!='no']

# %%
car=car[~car['engV'].isnull()]

# %%
car['engV'].isnull().sum()
# Out:
# 0

# %%
car['drive'].unique()
# Out:
# array(['full', 'rear', 'front', nan], dtype=object)

# %%
car['drive'].value_counts()
# Out:
# front    4696
# full     2364
# rear     1176
# Name: drive, dtype: int64

# %%
Front=['full', 'front',]

Back=['rear']

# %%
car['drive']=car['drive'].replace(Front,'Front').replace(Back,'Back')

# %%
car['drive'].value_counts()
# Out:
# Front    7060
# Back     1176
# Name: drive, dtype: int64

# %%
car['drive'].isnull().sum()
# Out:
# 377

# %%
car['drive'] = car['drive'].fillna('Front')

# %%
car['drive'].isnull().sum()
# Out:
# 0

# %%
car.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
car['body'].value_counts()
# Out:
# sedan        3248
# crossover    1951
# hatch        1105
# van           986
# other         752
# vagon         571
# Name: body, dtype: int64

# %%
car['body'].str.lower().unique()
# Out:
# array(['crossover', 'sedan', 'other', 'van', 'vagon', 'hatch'],
#       dtype=object)

# %%
Sedan='sedan'

Crossover='crossover'

Other='other'

Wagon='vagon'

Hatchback='hatch'

Van = 'van'

# %%
car['body']=car['body'].replace(Sedan,'Sedan').replace(Crossover,'Crossover').replace(Other,'Other').replace(Wagon,'Wagon').replace(Hatchback,'Hatchback').replace(Van,'Van')

# %%
car['body'].value_counts()
# Out:
# Sedan        3248
# Crossover    1951
# Hatchback    1105
# Van           986
# Other         752
# Wagon         571
# Name: body, dtype: int64

# %%
car.describe()
# Out:
#                price      mileage         engV         year
# count    8613.000000  8613.000000  8613.000000  8613.000000
# mean    16323.010025   134.336933     2.619971  2006.920817
# std     24595.680482    96.310756     5.785974     6.988229
# min         0.000000     0.000000     0.100000  1959.000000
# 25%      5699.000000    68.000000     1.600000  2005.000000
# 50%      9700.000000   124.000000     2.000000  2008.000000
# 75%     17500.000000   185.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
car[(car['mileage']==0) & (car['price']==0)]
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 20       Land Rover    0.0  Crossover        0   4.4  Diesel          yes
# 53    Mercedes-Benz    0.0  Crossover        0   3.0  Diesel          yes
# 70    Mercedes-Benz    0.0  Crossover        0   3.0  Diesel          yes
# 71           Toyota    0.0  Crossover        0   4.5  Diesel          yes
# 92             Audi    0.0  Crossover        0   3.0  Diesel          yes
# 105         Porsche    0.0  Crossover        0   3.0  Diesel          yes
# 125             BMW    0.0  Crossover        0   3.0  Diesel          yes
# 160   Mercedes-Benz    0.0  Crossover        0   3.0  Diesel          yes
# 756            Audi    0.0      Wagon        0   3.0  Diesel          yes
# 848           Dodge    0.0      Other        0   3.0  Diesel          yes
# 883           Dodge    0.0      Other        0   3.0  Diesel          yes
# 1028         Toyota    0.0  Crossover        0   4.5  Diesel          yes
# ...

# %%
car=car[~(car['mileage']==0) & ~(car['price']==0)]

# %%
((car['mileage']==0) & (car['price']==0)).sum()
# Out:
# 0

# %%
car.duplicated().value_counts()
# Out:
# False    8011
# True       67
# dtype: int64

# %%
car=car[~car.duplicated()]

# %%
car.duplicated().value_counts()
# Out:
# False    8011
# dtype: int64

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
car.describe()
# Out:
#                price      mileage         engV         year
# count    8011.000000  8011.000000  8011.000000  8011.000000
# mean    14906.697839   141.066409     2.592351  2006.466359
# std     18837.252047    94.087446     5.789659     6.865406
# min       259.350000     1.000000     0.100000  1959.000000
# 25%      5900.000000    77.000000     1.600000  2005.000000
# 50%      9600.000000   129.000000     2.000000  2008.000000
# 75%     16577.500000   189.000000     2.500000  2011.000000
# max    300000.000000   999.000000    99.990000  2016.000000

# %%
Q1=car.price.quantile(0.25)
Q3=car.price.quantile(0.75)

Q1,Q3
# Out:
# (5900.0, 16577.5)

# %%
IQR=Q3-Q1
LO=Q3-(1.5*IQR)
UO=Q3+(1.5*IQR)
LO,UO
# Out:
# (561.25, 32593.75)

# %%
car['price'].min()
# Out:
# 259.35

# %%
car['price'].median()
# Out:
# 9600.0

# %%
car['price']=np.where(car['price']>UO,UO,np.where(car['price']==0,car['price'].min(),car['price']))

# %%
car.describe()
# Out:
#               price      mileage         engV         year
# count   8011.000000  8011.000000  8011.000000  8011.000000
# mean   12449.056432   141.066409     2.592351  2006.466359
# std     9045.881912    94.087446     5.789659     6.865406
# min      259.350000     1.000000     0.100000  1959.000000
# 25%     5900.000000    77.000000     1.600000  2005.000000
# 50%     9600.000000   129.000000     2.000000  2008.000000
# 75%    16577.500000   189.000000     2.500000  2011.000000
# max    32593.750000   999.000000    99.990000  2016.000000

# %%
plt.boxplot(car['price'])
plt.show()

# %%
car.to_csv('new price cleaned car.csv')

# %%
car.describe()
# Out:
#               price      mileage         engV         year
# count   8011.000000  8011.000000  8011.000000  8011.000000
# mean   12449.056432   141.066409     2.592351  2006.466359
# std     9045.881912    94.087446     5.789659     6.865406
# min      259.350000     1.000000     0.100000  1959.000000
# 25%     5900.000000    77.000000     1.600000  2005.000000
# 50%     9600.000000   129.000000     2.000000  2008.000000
# 75%    16577.500000   189.000000     2.500000  2011.000000
# max    32593.750000   999.000000    99.990000  2016.000000

# %%
QM1=car.mileage.quantile(0.25)
QM3=car.mileage.quantile(0.75)

QM1,QM3
# Out:
# (77.0, 189.0)

# %%
IQRM=QM3-QM1
LOM=QM3-(1.5*IQRM)
UOM=QM3+(1.5*IQRM)
LOM,UOM
# Out:
# (21.0, 357.0)

# %%
car['mileage']=np.where(car['mileage']>UOM,UOM,np.where(car['mileage']<LOM,LOM,car['mileage']))

# %%
(car['mileage']>357).sum()
# Out:
# 0

# %%
plt.boxplot(car['mileage'])
plt.show()

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
car.describe()
# Out:
#               price      mileage         engV         year
# count   8011.000000  8011.000000  8011.000000  8011.000000
# mean   12449.056432   139.816128     2.592351  2006.466359
# std     9045.881912    83.734510     5.789659     6.865406
# min      259.350000    21.000000     0.100000  1959.000000
# 25%     5900.000000    77.000000     1.600000  2005.000000
# 50%     9600.000000   129.000000     2.000000  2008.000000
# 75%    16577.500000   189.000000     2.500000  2011.000000
# max    32593.750000   357.000000    99.990000  2016.000000

# %%
car.duplicated().value_counts()
# Out:
# False    7972
# True       39
# dtype: int64

# %%
car=car[~car.duplicated()]

# %%
car.duplicated().value_counts()
# Out:
# False    7972
# dtype: int64

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [markdown]
# ## Rule

# %%
'''
Relevant
Resonable 
non Vague
'''
# Out:
# '\nRelevant\nResonable \nnon Vague\n'

# %%
car.head()
# Out:
#              car     price       body  mileage  engV engType registration  \
# 0           Ford  15500.00  Crossover     68.0   2.5     Gas          yes
# 1  Mercedes-Benz  20500.00      Sedan    173.0   1.8     Gas          yes
# 2  Mercedes-Benz  32593.75      Other    135.0   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.00        Van    162.0   1.8  Diesel          yes
# 5         Nissan  16600.00  Crossover     83.0   2.0  Petrol          yes
#
#    year    model  drive
# 0  2010     Kuga  Front
# 1  2011  E-Class   Back
# 2  2008   CL 550   Back
# 3  2012    B 180  Front
# 5  2013  X-Trail  Front

# %%
car.describe()
# Out:
#               price      mileage         engV         year
# count   7972.000000  7972.000000  7972.000000  7972.000000
# mean   12350.506125   140.350477     2.590582  2006.423357
# std     8957.293905    83.572945     5.803326     6.854055
# min      259.350000    21.000000     0.100000  1959.000000
# 25%     5850.000000    78.000000     1.600000  2004.000000
# 50%     9600.000000   130.000000     2.000000  2008.000000
# 75%    16500.000000   189.000000     2.500000  2011.000000
# max    32593.750000   357.000000    99.990000  2016.000000

# %%
sns.boxplot(data=car, y='price',x='registration',order=["yes", "no"])
# Out:
# <AxesSubplot:xlabel='registration', ylabel='price'>

# %% [markdown]
# ## '''Total car  '''

# %%
paper = plt.figure(figsize = (15,5))

car['car'].value_counts().plot.bar()

plt.xlabel('Name of cars')
plt.ylabel('Number of cars ')
plt.title('Cars')
plt.grid(b=True)
plt.show()

# %% [markdown]
# ## '''  Top 10 Cars'''

# %%
paper = plt.figure(figsize = (15,5))

plot=car['car'].value_counts()[:10].plot.bar()

for p in plot.patches:
    plot.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)
    
plt.xlabel('Name of cars')
plt.ylabel('Number of cars')
plt.title('Top 10 car ')

plt.grid(b=True)

plt.show()

# %% [markdown]
# ## '''Top 20 lowest cars'''

# %%
paper = plt.figure(figsize = (15,5))

car['car'].value_counts()[-20:].plot.bar()
plt.xlabel('Name of cars')
plt.ylabel('Number of cars')
plt.title('Top 20 lowest car')
plt.grid(b=True)
plt.show()

# %% [markdown]
# ## ''' Year wise Cars'''

# %%
figure = plt.figure(figsize=[15, 7])

plot=car['year'].value_counts().plot.bar()

for p in plot.patches:
    plot.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)

plt.xlabel(xlabel='year', size=14)

plt.ylabel(ylabel='No. of cars', size=14)

plt.title(label='Year wise cars ', size=16)

plt.grid(b=True)

plt.show()

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data=car[car.year > 2000], x = 'year' ,element='bars', fill=True, multiple="stack",thresh=2,legend=True)
plt.title("No. of Cars vs Recent year ")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=car[car.year > 2010], x='year', y='price')
plt.title("price vs Latest 6 year ")
plt.show()

# %% [markdown]
# ## '''Cars based on body type'''

# %%
figure = plt.figure(figsize=[15, 7])


plot=car['body'].value_counts().plot.bar()

for p in plot.patches:
    plot.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)

plt.xlabel(xlabel='Body Types', size=14)

plt.ylabel(ylabel='No. of cars', size=14)

plt.title(label='cars based on Body Types ', size=16)

plt.grid(b=True)

plt.show()

# %% [markdown]
# ## '''Cars based on Engine Type'''

# %%
figure = plt.figure(figsize=[15, 7])


plot=car['engType'].value_counts().plot.bar()

for p in plot.patches:
    plot.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)

plt.xlabel(xlabel='Engine types', size=14)

plt.ylabel(ylabel='No. of cars', size=14)

plt.title(label='Based on Engine Types', size=16)

plt.grid(b=True)

plt.show()

# %% [markdown]
# ## '''Cars based on Drive'''

# %%
figure = plt.figure(figsize=[10, 5])


plot=car['drive'].value_counts().plot.bar()

for p in plot.patches:
    plot.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)

plt.xlabel(xlabel='Drive', size=14)

plt.ylabel(ylabel='No. of car sales', size=14)

plt.title(label='car sales based on Drive', size=16)

plt.grid(b=True)

plt.show()

# %% [markdown]
# ## '''Cars based on price'''

# %%
paper = plt.figure(figsize = [15,7])
sns.displot(data=car,x='price',kde=True)
plt.title("No. of Cars vs price")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ## '''Cars based on Mileage'''

# %%
paper = plt.figure(figsize = [15,7])
sns.displot(data=car,x='mileage',kde=True,height=5, aspect=1)
plt.title("No. of Cars vs Mileage")
plt.grid(b=True)
plt.show()

# %% [markdown]
# ## '''No. of  Cars After 2012 '''

# %%
paper = plt.figure(figsize = [20,25])

sns.histplot(data=car[car.year > 2012], x = 'year'  ,hue = 'car',element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of  Cars After 2012")
plt.show()

# %% [markdown]
# ## '''No. of Cars vs Price based on engType"'

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car, x = 'price' ,hue = 'engType',element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of Cars vs Price based on engType")
plt.show()

# %% [markdown]
# ## '''No. of Cars vs Year based on engType"'

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car,x='year',hue='engType', element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of Cars vs Year based on engType")

plt.show()

# %% [markdown]
# ## '''Overall car prices based on  Engine type"'

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=car, x='year', y='price', hue='engType',legend= True)
plt.title("Overall car prices based on  Engine type")
plt.show()

# %% [markdown]
# ## '''Price vs Engine types'''

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=car, x='engType', y='price')
plt.title('Price vs Engine types')
plt.show()

# %% [markdown]
# ## '''Latest 6 year car prices by Engine type"'

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=car[car.year > 2010], x='year', y='price', hue='engType')
plt.title("Latest 6 year car prices by engine type")
plt.show()

# %% [markdown]
# ## '''No. of Cars vs Year based on Body"'

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car,x='year',hue='body', element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of Cars vs Year based on Body")
plt.show()

# %% [markdown]
# ## '''No. of Cars vs Price based on Body'''

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car,x='price',hue='body',  element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of Cars vs Price based on Body")
plt.show()

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car,x='body',hue='drive',  element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("No. of Cars vs Body based on Drive")
plt.show()

# %% [markdown]
# ## '''Price vs Year based on Body Type'''

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=car, x='year', y='price', hue='body',legend= True)
plt.title("prices vs Year  based Body type")
plt.show()

# %% [markdown]
# ## '''Latest 6 year No. of cars based on  Body type'''

# %%
paper = plt.figure(figsize = [15,7])

sns.histplot(data = car[car.year >2010],x='year',hue='body', element='bars', fill=True, multiple="stack", shrink=1,thresh=1,legend=True)
plt.title("Latest 6 year No. of cars based on  Body type")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=car[car.year > 2010], x='year', y='price', hue='body',legend= True)
plt.title("Latest 6 year car prices by Body type")
plt.show()

# %% [markdown]
# ## ''' Price vs Mileage'''

# %%
plt.figure(figsize=(18,7))

sns.regplot(x='price', y='mileage', data=car, color='brown',)
plt.xticks(ticks=np.arange( 0, 34000,1000), size=8)

plt.yticks(ticks=np.arange(0, 400, 20), size=12)

plt.xlabel(xlabel='price', size=14)

plt.ylabel(ylabel='mileage', size=14)

plt.title(label='price vs mileage', size=16)

plt.show()

# %% [markdown]
# ## '''Mileage vs Engine type'''

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data=car, x='engType', y='mileage')
plt.title('Mileage vs Engine types')
plt.show()

# %% [markdown]
# ## '''Latest 6 year price vs mileage'''

# %%
plt.figure(figsize=(18,7))

sns.regplot(x='price', y='mileage', data=car[car.year > 2010], color='brown',)
plt.xticks(ticks=np.arange( 0, 34000,1000), size=8)

plt.yticks(ticks=np.arange(0, 400, 20), size=12)

plt.xlabel(xlabel='price', size=14)

plt.ylabel(ylabel='mileage', size=14)

plt.title(label='Latest 6 year price vs mileage', size=16)

plt.show()

# %% [markdown]
# ## '''Average price of vehicles by engine type and drive'''

# %%
fig, ax = plt.subplots(figsize=(16,8))

sns.barplot(x="engType", y="price", hue= "body", palette="husl",data=car)
ax.set_title("Average price of vehicles by engine type and drive",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ## '''Car sales based on  EngType vs  Drive '''

# %%
f, ax = plt.subplots(nrows=1, ncols=4, figsize=(20, 8))

engType = list(car['engType'].unique())
custom_index = [0, 1, 2, 3]

for i, j in zip(engType, custom_index):
  car['drive'][car['engType']==i].value_counts() \
                                              .plot \
                                              .pie(explode=[0, 0.2],
                                                   autopct='%1.1f%%',
                                                   wedgeprops=dict(width=0.15), 
                                                   ax=ax[j], shadow=True)
  ax[j].set_title(label='EngType - '+i, size=16)
  ax[j].set_ylabel(ylabel='Drive', size=14)



plt.show()

# %% [markdown]
# ## '''Analysis Top 5 Cars sales in Latest 6 Year'''

# %%
vol = car.loc[car['car'] == 'Volkswagen']
mar = car.loc[car['car'] == 'Mercedes-Benz']
bmw = car.loc[car['car'] == 'BMW']
tyt = car.loc[car['car'] == 'Toyota']
vaz = car.loc[car['car'] == 'VAZ']

# %%
plt.figure(figsize=(5,5))
sns.histplot(data=vol[vol.year > 2009], x = 'year'  ,hue = None,element='bars',shrink=1,bins='auto',stat='count')
plt.title("Volkswagen")

plt.show()

# %%
plt.figure(figsize=(5,5))

sns.histplot(data=mar[mar.year > 2009], x = 'year'  ,hue = None,element='bars',shrink=1,bins='auto',stat='count')
plt.title("Mercedes-Benz")
plt.show()

# %%
plt.figure(figsize=(5,5))

sns.histplot(data=bmw[bmw.year > 2009], x = 'year'  ,hue = None,element='bars',shrink=1,bins='auto',stat='count')
plt.title("BMW")
plt.show()

# %%
plt.figure(figsize=(5,5))

sns.histplot(data=tyt[tyt.year > 2009], x = 'year'  ,hue = None,element='bars',shrink=1,bins='auto',stat='count')
plt.title("Toyota")
plt.show()

# %%
plt.figure(figsize=(5,5))

sns.histplot(data=vaz[vaz.year > 2009], x = 'year'  ,hue = None,element='bars',shrink=1,bins='auto',stat='count')
plt.title("VAZ")
plt.show()

# %% [markdown]
# ## '''CORRELATION'''

# %%
plt.subplots(figsize=(15,7))
print(car.corr())
dataplot = sns.heatmap(car.corr(), cmap="YlGnBu", annot=True)
plt.title('CORRELATION')
plt.show()
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.356247  0.051558  0.535948
# mileage -0.356247  1.000000  0.055323 -0.468449
# engV     0.051558  0.055323  1.000000 -0.054335
# year     0.535948 -0.468449 -0.054335  1.000000

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# 1. **Volkswagen,Mercedes-Benz and BMW**  are the **Top 3** and **Buick,Saab and FAW** are the **least** car selling brand.
# 2. Most cars happening price range is between **2000** to **15000** .
# ![image-17.png](attachment:image-17.png)
# 3. There are very few cars sold in **20000 to 33000** price bracket, which is best competitive price range.
# ![image-17.png](attachment:image-17.png)
# 4. Most cars happening Mileage range is belong to **50 to 200** and very less Cars in range of after **250**.
# ![image-18.png](attachment:image-18.png)
# 5. **Gas and Diesel** engine provides higher mileage.
# ![image-22.png](attachment:image-22.png)
# 6. Though the cars with **Gas engine type** sold at most economical price, in the recent days customers are not preferred.
# ![image-21.png](attachment:image-21.png)
# 7. Even with effordable price range, **gas engine type** cars are least preferred.
# ![image-22.png](attachment:image-22.png)
# 8. **Front** wheel drive cars mostly opted by customers. **Back** wheel drive car sales are very least prefferd by customers.
# ![image-16.png](attachment:image-16.png)
# 9. Most preferred
#    engine types are **Petrol and Diesel**.
#    ![image-20.png](attachment:image-20.png)
# 10. Irrespective of tenure, **Sedans** are always on demand follows with **Cross-over** and **Hatchback** .
# ![image-19.png](attachment:image-19.png)
# 11. From **2015**,the car price of **other engType or Wagon body type** drastically **decreases** and from 2014 Van body type price are **increase** drastically.
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# 12. In recent year **Crossovers** are leading in sales followed by **sedans**.
# ![image-5.png](attachment:image-5.png)
# 13. As we know that demands of car are decrease over the year and also the same situation in the top 5 selling company Car Brand but in which **BMW and VAZ** are doing good in recent year or **Volkswagen** are remain same.
# ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
# ![image-14.png](attachment:image-14.png)
# ![image-15.png](attachment:image-15.png)
# 14.Correlation between mileage vs price or Year is **negative** but The correlation between
# engV vs Price which is **positive**.
# ![image-24.png](attachment:image-24.png)

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# 1. **Cars should be available from all price ranges.**
# 2. As **2000 to 15000 /-** Dollar is the most sales happening price range and there are very few cars sold in **20000 to 33000** price bracket, which is best competitive price range., procuring these price ranged cars should potentially improves the sales,Sense the customer likeihood and market more such cars.
# 3. **Petrol and Diesel** cars are most popular.
# 4. **Front** wheel drive is most preferred in Crossovers and Sedan cars.
#    So bring more inventory from most value for money branded cars like Mercedes-Benz, Toyota, BMW, Volkswagen etc.. **Crossovers and Sedans with front wheel drive.**
#
# 5. Market & Procure more latest, future ready and sophisticated cars like **Engine type other (Hybrid and Electric cars).** Despite the fact that car sales fluctuated across years, the Other cars sales are consistent and seen ramp up in sales recently with lesser price.
# 6. Immediate **tactical approach and Impressive strategic approach**
#
#    **Tactical Approach**
#    Less preferred old cars should be announced with great deals and clear the stock. In that way we can save money, renting space for storage
#    Procure more demanded cars like Mercedes-Benz, BMW, Volkswagen, Toyota, Vaz, Audi.. etc
#
#    **Strategic Approach**
#    Economy cars are ideally most selling. And most recent economy car are gas engines which are not preferred by customers. So procure more Economy price range cars which is of Petrol or Diesel engine type
